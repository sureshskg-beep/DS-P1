# %%
import pandas as pd

# %%
titanic_data = pd.read_csv("Titanic_Data.csv")

# %%
titanic_data.head(100)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..          ...     ...                                                ...
# 95          987       3                         Tenglin, Mr. Gunnar Isidor
# 96          988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 97          989       3                          Makinen, Mr. Kalle Edvard
# 98          990       3                       Braf, Miss. Elin Ester Maria
# 99          991       3                       Nancarrow, Mr. William Henry
#
# ...

# %%
# Condition based Fintering

# %%
mask = titanic_data["Fare"]>100

# %%
fare_100 = titanic_data [mask]

# %%
fare_100.shape
# Out:
# (31, 11)

# %%
fare_100.head(100)
# Out:
#      PassengerId  Pclass                                               Name  \
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 53           945       1                         Fortune, Miss. Ethel Flora
# 59           951       1                        Chaudanson, Miss. Victorine
# 64           956       1                        Ryerson, Master. John Borie
# 69           961       1                Fortune, Mrs. Mark (Mary McDougald)
# 74           966       1                               Geiger, Miss. Amalie
# 75           967       1                                 Keeping, Mr. Edwin
# 81           973       1                                 Straus, Mr. Isidor
# 114         1006       1             Straus, Mrs. Isidor (Rosalie Ida Blun)
# 141         1033       1                               Daniels, Miss. Sarah
# 142         1034       1                         Ryerson, Mr. Arthur Larned
# ...

# %%
female_fare_100 = fare_100[fare_100.Sex == "famale"]

# %%
female_fare_100.shape
# Out:
# (0, 11)

# %%
titabic_data[
    (titanic_data.Fare>100) & (titanic_data.Sex == "famale")
    ]
female_fare_100.head()
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
survived_female = titanic_data[
    (titanic_data('Sex') =="female") & (titanic_data.Survived == 1)
]
survived_female.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 survived_female = titanic_data[
# ----> 2     (titanic_data('Sex') =="female") & (titanic_data.Survived == 1)
#       3 ]
#       4 survived_female.shape
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# # Filtering using existing methods

# %%
# isna()

# %%
null_cabin = titanic_data[titanic_data.Cabin.isna(0)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 null_cabin = titanic_data[titanic_data.Cabin.isna(0)]
#
# TypeError: Series.isna() takes 1 positional argument but 2 were given
