# %%
flag = True

# %%
type(flag)
# Out:
# bool

# %%
c = 5 > 6

# %%
c
# Out:
# False

# %%
x = True
y = False

# %%
x and y
# Out:
# False

# %%
x & y
# Out:
# False

# %%
x or y
# Out:
# True

# %%
x | y
# Out:
# True

# %%
not x
# Out:
# False

# %%
(5 < 6) and (7 !=0 )  # ! = is not equal to
# Out:
# True

# %%
number = 9-5-4
result = bool(number)

# %%
print(result)
# Out:
# False

# %%
# 0 element is false and 1 element is true
