# %%
num = 7642
["even","odd"][num%2]
# Out:
# 'even'

# %%
num = 7641
["even","odd"][num%2]
# Out:
# 'odd'

# %%
numbers = 7641
numbers = [["even","odd"][numbers % 2] for numbers in range(1,11) ]

# %%
##Set Comprehension

# %%
squared = {num**2 for num in range (1,11) if num % 2 !=0}
squared
# Out:
# {1, 9, 25, 49, 81}

# %%
letters = ["a" , "b" , "c"]

pairs = { let1 + let2 for let1 in letters for let2 in letters}

# %%
pairs
# Out:
# {'aa', 'ab', 'ac', 'ba', 'bb', 'bc', 'ca', 'cb', 'cc'}
