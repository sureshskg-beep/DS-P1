# %% [markdown]
# # chek leap year

# %%
def check_leap_year(year: int):
    if (year % 4 ==0 and year % 100 !=0):
         print("Leap Year")
    else:
        print("Not a Leap Year")

# %%
check = check_leap_year(2028)
# Out:
# Leap Year

# %%
list_years = [2024, 2023, 1900, 2000, 2400, 2100, 4, 2019, 221]

# %%
check = check_leap_year(list_yesrs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 check = check_leap_year(list_yesrs)
#
# NameError: name 'list_yesrs' is not defined
