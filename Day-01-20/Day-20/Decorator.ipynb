# %%
import time
import random

def timeit(func):
    def wrapper():
        start_time = time.time()
        result = func()                               
        end_time = time.time()        
        
        print("total_time taken: ", round(end_time - start_time, 3), "secs")
        
        return result
    return wrapper

# %%
@timeit
def heavy_work():
    end_time = time.time() + random.uniform(1,10)
    
    result

# %%
@star
@percent
@timeit

def printermsg):
    print(msg)
    
    Printer("hello")
# Out:
#   Cell In[9], line 5
#     def printermsg):
#                   ^
# SyntaxError: unmatched ')'

# %%
heavy_work()
# Out:
# Time taken: 0.09927868843078613 seconds
