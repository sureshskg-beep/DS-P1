# %%
date1 = "2025-12-02"
date2 = "06/12/2050"

# %%
date2>date1
# Out:
# False

# %%
date2-date1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 date2-date1
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
import datetime

date3 = datetime.date(2010, 12, 31)

# %%
today = datetime.date.today()

# %%
today > date3
# Out:
# True

# %%
# strftime

today = datetime.date.today()
today.strftime("%B %d, %Y")
# Out:
# 'December 15, 2025'

# %% [markdown]
# ### Time

# %%
import time

# %%
time.time()
# Out:
# 1765767289.923915

# %%
time.ctime()
# Out:
# 'Mon Dec 15 08:39:58 2025'

# %%
print("Loding ...")
time.sleep(5)
print("Completed !")
# Out:
# Loding ...
# Completed !

# %%
time.localtime()
# Out:
# time.struct_time(tm_year=2025, tm_mon=12, tm_mday=15, tm_hour=8, tm_min=42, tm_sec=26, tm_wday=0, tm_yday=349, tm_isdst=0)

# %%
time.strftime("%H hour, %M minutes and %S seconds")
# Out:
# '08 hour, 45 minutes and 43 seconds'

# %%
start = time.time()

print("hello")
time.sleep(10)

end = time.time()
# Out:
# hello

# %%
end - start
# Out:
# 10.001471757888794
