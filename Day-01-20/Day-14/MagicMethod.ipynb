# %% [markdown]
# ### MagicMethod
#
# In Python, Magic Methods (also called dunder methods, short for double underscore) are special methods with names that start and end with double underscores, like __init__, __str__, __add__, etc.
#
# They allow you to customize the behavior of your classes — for example, how objects are created, represented, compared, or used with operators.
#
# Common Magic Methods
#
# Method	Purpose:
#
# __init__(self, ...)	Constructor, called when creating an object.
# __str__(self)	Defines the string representation for print() or str().
# __repr__(self)	Official string representation, used in debugging.
# __len__(self)	Defines behavior for len(obj).
# __getitem__(self, key)	Enables indexing like obj[key].
# __setitem__(self, key, value)	Enables item assignment.
# __delitem__(self, key)	Enables item deletion.
# __iter__(self)	Makes the object iterable.
# __next__(self)	Returns the next item in iteration.
# __add__(self, other)	Defines behavior for + operator.
# __eq__(self, other)	Defines equality ==.
# __lt__(self, other)	Defines < comparison.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

# %%
person = Person("Humilton", 32)

# %%
person.name
# Out:
# 'Humilton'

# %%
person.age
# Out:
# 32

# %%
print(person)

# %%
name = str("Hari")

# %%
print(name)
# Out:
# Hari

# %%
dir(Person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
class Point: 
    """
    Operation on Points.
    """
    def __init__(self, x,y):
        self.x = x
        self.y = y
        
    def __str__(self):
        return f"Point( {self.x}, {self.y})"
    
    def __add__(self, other):
        x = self.x + other.x
        y = self.y + other.y
        return Point(x,y)
    
    def __mul__(self, other):
        x = self.x * other.x
        y = self.y * other.y
        return Point(x,y)
    
      def __eq__(self, other):
        return self.x == other.x and self.y == other.y
# Out:
#   File <string>:22
#     def __eq__(self, other):
#                             ^
# IndentationError: unindent does not match any outer indentation level

# %%
A = Point(3,4)

B = Point(6,7)

# %%
# Out:
# Point( 3, 4)

# %%
C = A * B

# %%
print(C)
# Out:
# Point( 18, 28)

# %%
print(C)
# Out:
# Point( 18, 28)

# %%
A == B
# Out:
# False

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 import pandas
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pandas.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 pandas.__version__
#
# NameError: name 'pandas' is not defined
