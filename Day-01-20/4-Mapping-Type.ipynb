# %%
## Mapping typeabs

# %%
person = {
    'age' : 60,
    'gender' :'male',
    'pet' : True,
    1: ['maths', 'science'],
    'city': 'baltimore'}

# %%
person
# Out:
# {'age': 60,
#  'gender': 'male',
#  'pet': True,
#  1: ['maths', 'science'],
#  'city': 'baltimore'}

# %%
type (person)
# Out:
# dict

# %%
person.keys()
# Out:
# dict_keys(['name', 'city'])

# %%
person["city"]
# Out:
# 'baltimore'

# %%
person.get("DOB", 1990)
# Out:
# 1990

# %%
person.get("age", "unknown")
# Out:
# 60

# %%
#modifying Elements

# %%
print(person)
# Out:
# {'age': 60, 'gender': 'male', 'pet': True, 1: ['maths', 'science'], 'city': 'baltimore'}

# %%
person.pop('city')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 person.pop('city')
#
# KeyError: 'city'

# %%
person
# Out:
# {'age': 60, 'gender': 'male', 'pet': True, 1: ['maths', 'science']}

# %%
person{1}
# Out:
#   Cell In[44], line 1
#     person{1}
#           ^
# SyntaxError: invalid syntax

# %%
person[1]
# Out:
# ['maths', 'science']

# %%
person[1].pop()
# Out:
# 'science'

# %%
person
# Out:
# {'age': 60, 'gender': 'male', 'pet': True, 1: ['maths'], 'city': 'baltimore'}

# %%
person
# Out:
# {'gender': 'male', 'pet': True, 1: ['maths'], 'city': 'baltimore'}

# %%
person.popitem()
# Out:
# ('city', 'baltimore')

# %%
person.keys()
# Out:
# dict_keys(['gender', 'pet', 1])

# %%
person.values()
# Out:
# dict_values(['male', True, ['maths']])

# %%
person
# Out:
# {'gender': 'male', 'pet': True, 1: ['maths']}

# %%
Marks = {"math" : 90, "Science" : "F"}

# %%
new_dict = person | Marks
new_dict
# Out:
# {'gender': 'male', 'pet': True, 1: ['maths'], 'math': 90, 'Science': 'F'}

# %%
dict(
    sorted(
        person.items(),
        reverse = False
    )
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 2
#       1 dict(
# ----> 2     sorted(
#       3         person.items(),
#       4         reverse = False
#       5     )
#       6 )
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 test
#
# NameError: name 'test' is not defined

# %%
{int: 'value'}
# Out:
# {int: 'value'}

# %%
test[int]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 test[int]
#
# NameError: name 'test' is not defined

# %%
int
# Out:
# int

# %%
False
# Out:
# False

# %%
False
# Out:
# False

# %%
person = {
    "name": "Hari Baral",
    "age": 30, 
    "gender": "Male",
    "pet" : True,
    "scroes": ["math", "Science"]
}
