# %%
try:
    num = int(input("enter a number "))
    print(num ** 5)
    
except ValueError as e:
    print(e)
    print("Invlid input, enter integer value")
    print(0)
# Out:
# enter a number rg
# invalid literal for int() with base 10: 'rg'
# Invlid input, enter integer value
# 0

# %%
try:
    num = int(input("enter a number "))
    print(15 / num)
    
except ValueError as e:
    print(e)
    print("Invlid input, enter integer value")
    print(0)
# Out:
# enter a number 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 try:
#       2     num = int(input("enter a number "))
# ----> 3     print(15 / num)
#       5 except ValueError as e:
#       6     print(e)
#
# ZeroDivisionError: division by zero

# %%
try:
    num = int(input("enter a number "))
    print(num ** 5)
    
except Exception as e:
    print(e)
    print("Invlid input, enter integer value")
    print(0)
# Out:
# enter a number ssk
# invalid literal for int() with base 10: 'ssk'
# Invlid input, enter integer value
# 0

# %% [markdown]
# ## Catching Multiple Exceptions:

# %%
try: 
    x = float(input("Enter a number"))
    y = int(input("Enter another no."))
    result = x/y
    
except ValueError as err:
    print("Invalid Input", err)
    result = 1
    
except ZeroDivisionError:
    print("Cannot Divide by 0")
    result = 0
    
except Exception as e:
    print(e)
    result = 0
# Out:
# Enter a number0
# Enter another no.0
# Cannot Divide by 0

# %%
try: 
    x = float(input("Enter a number"))
    y = int(input("Enter another no."))
    result = x/y
    
except ValueError as err:
    print("Invalid Input", err)
    result = 1
    
except ZeroDivisionError:
    print("Cannot Divide by 0")
    result = 0
    
except Exception as e:
    print(e)
    result = 0
# Out:
# Enter a number5
# Enter another no.0
# Cannot Divide by 0

# %%
try: 
    x = float(input("Enter a number"))
    y = int(input("Enter another no."))
    result = x/y
    
except ValueError as err:
    print("Invalid Input", err)
    result = 1
    
except ZeroDivisionError:
    print("Cannot Divide by 0")
    result = 0
    
except Exception as e:
    print(e)
    result = 0
# Out:
# Enter a numberrx
# Invalid Input could not convert string to float: 'rx'

# %% [markdown]
# # The Finally Block

# %%
try: 
    x = float(input("Enter a number"))
    y = int(input("Enter another no."))
    result = x/y
    
except ValueError as err:
    print("Invalid Input", err)
    result = 1
    
except ZeroDivisionError:
    print("Cannot Divide by 0")
    result = 0
    
else:
    print("final Result", result)
    
finally:
    print("The End")
# Out:
# Enter a number4
# Enter another no.0
# Cannot Divide by 0
# The End

# %%
lst = ["a", "b", "c", "d"]

# %%
def get_elements(index):
    return lst[index]

# %%
inp = 2

try:
    result = get_elements(inp)
    
except IndexError:
    print("[ERROR]: Reverting to last index")
    result = get_elements(-1)
    
finally:
    print(result)
# Out:
# c

# %%
inp = 5

try:
    result = get_elements(inp)
    
except IndexError:
    print("[ERROR]: Reverting to last index")
    result = get_elements(-1)
    
finally:
    print(result)
# Out:
# [ERROR]: Reverting to last index
# d

# %%
Football (22)
22 players picture

Team_define <22 error
