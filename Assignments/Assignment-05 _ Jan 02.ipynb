# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
housing_price = pd.read_csv("Housing_Price.csv")
housing_price.head
# Out:
# <bound method NDFrame.head of         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
sns.lineplot(data=housing_price)
# Out:
# <Axes: >

# %%
plt.figure(figsize = (14,4)),
plt.title("Housing Price in xxx - xx period"), 
sns.lineplot(data = housing_price)
# Out:
# <Axes: title={'center': 'Housing Price in xxx - xx period'}>

# %%
list(housing_price.columns)
# Out:
# ['price',
#  'area',
#  'bedrooms',
#  'bathrooms',
#  'stories',
#  'mainroad',
#  'guestroom',
#  'basement',
#  'hotwaterheating',
#  'airconditioning',
#  'parking',
#  'prefarea',
#  'furnishingstatus']

# %%
plt.figure(figsize = (12,4)),
plt.title("Housing Price in xxx - xx period"), 
sns.lineplot(data = housing_price["price"], label ="House Price")
sns.lineplot(data =housing_price["stories"], label = "House Story")
plt.xlabel("date")
# Out:
# Text(0.5, 0, 'date')
