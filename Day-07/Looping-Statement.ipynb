# %%
## Loop

# %%
for i in range(5):
    print("Hello")
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
person = {
    "name": "SKG",
    "age" : 40,
    "gender": "Male"
}

# %%
for p in person.items():
    print(p)
# Out:
# ('name', 'SKG')
# ('age', 40)
# ('gender', 'Male')

# %%
coord = [
    [1,23],[4,65],[7,9]
]

# %%
for x,y in coord:
    print(x,y)
# Out:
# 1 23
# 4 65
# 7 9

# %%
for x,y in coord:
    print(x)
# Out:
# 1
# 4
# 7

# %%
for x,y in coord:
    print(y)
# Out:
# 23
# 65
# 9
