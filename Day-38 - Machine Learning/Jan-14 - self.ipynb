# %%
import pandas as pd
import numpy as np

# %%
data_df = pd.read_csv("https://www.statlearning.com/s/Advertising.csv", index_col=0)
data_df
# Out:
#         TV  radio  newspaper  sales
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
data_df.plot(kind = "scatter")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data_df.plot(kind = "scatter")
#
# File ~\Desktop\DSML\Projects\DS-P1\.venv\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     973 if kind in self._dataframe_kinds:
#     974     if isinstance(data, ABCDataFrame):
# --> 975         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     976     else:
#     977         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File ~\Desktop\DSML\Projects\DS-P1\.venv\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:70, in plot(data, kind, **kwargs)
#      68             ax = plt.gca()
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      71 plot_obj.generate()
#      72 plot_obj.draw()
#
# File ~\Desktop\DSML\Projects\DS-P1\.venv\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1327, in ScatterPlot.__init__(self, data, x, y, s, c, colorbar, norm, **kwargs)
#    1324 self.colorbar = colorbar
#    1325 self.norm = norm
# -> 1327 super().__init__(data, x, y, **kwargs)
#    1328 if is_integer(c) and not self.data.columns._holds_integer():
#    1329     c = self.data.columns[c]
#
# File ~\Desktop\DSML\Projects\DS-P1\.venv\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1255, in PlanePlot.__init__(self, data, x, y, **kwargs)
#    1253 MPLPlot.__init__(self, data, **kwargs)
#    1254 if x is None or y is None:
# -> 1255     raise ValueError(self._kind + " requires an x and y column")
#    1256 if is_integer(x) and not self.data.columns._holds_integer():
#    1257     x = self.data.columns[x]
#
# ValueError: scatter requires an x and y column
