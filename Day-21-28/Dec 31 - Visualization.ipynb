# %%
import pandas as pd

# %%
titanic_df = pd.read_csv("Titanic_data.csv")

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp313-cp313-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.10.8-cp313-cp313-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Installing collected packages: cycler, contourpy, matplotlib
#
#    ------------- -------------------------- 1/3 [contourpy]
#    ------------- -------------------------- 1/3 [contourpy]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    ---------------------------------------- 3/3 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 matplotlib-3.10.8

# %% [markdown]
# # Visualization
#
# Bar Graph
# Line Graph
# Histogram
# Pie Chart
# Heatmap
# Scratter Plot/dot pot, Box Plot, Graph Plot
#
# Bubbl Chart
# Pyramid Chart
# Violien Chart

# %% [markdown]
# ## 1. Bar Chart

# %%
titanic_df["Survived"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Survived'>

# %%
titanic_df["Sex"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Sex'>

# %%
corr_matrix = titanic_df[["Age", "Fare", "Pclass", "Survived"]].dropna().corr()
corr_matrix
# Out:
#                Age      Fare    Pclass  Survived
# Age       1.000000  0.096067 -0.369226 -0.077221
# Fare      0.096067  1.000000 -0.554182  0.268189
# Pclass   -0.369226 -0.554182  1.000000 -0.359653
# Survived -0.077221  0.268189 -0.359653  1.000000

# %%
# !pip install seaborn
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from seaborn) (2.4.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\suresh\desktop\dsml\projects\ds-p1\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
