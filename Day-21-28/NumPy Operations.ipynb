# %%
import numpy as np

# %%
a = np.array([[4,5,6], [1,2,4]])
b = np.array([[8,6,0], [3,2,4]])

# %%
a, b
# Out:
# (array([[4, 5, 6],
#         [1, 2, 4]]),
#  array([[8, 6, 0],
#         [3, 2, 4]]))

# %%
a + b # can also use function np.add(a,b)
# Out:
# array([[12, 11,  6],
#        [ 4,  4,  8]])

# %%
np.subtract(a,b)  # also use a-b
# Out:
# array([[-4, -1,  6],
#        [-2,  0,  0]])

# %%
# a**2
np.pow(a, 2)
# Out:
# array([[16, 25, 36],
#        [ 1,  4, 16]])

# %%
# a % b

quo, rem = np.divmod(a,b)
quo
# Out:
# C:\Users\Suresh\AppData\Local\Temp\ipykernel_22992\3604446247.py:3: RuntimeWarning: divide by zero encountered in divmod
#   quo, rem = np.divmod(a,b)
# array([[0, 0, 0],
#        [0, 1, 1]])

# %%
c = np.array([[8,4,0], [3,11,4]]) # adding 3rd array

# %% [markdown]
# ## Trignometric

# %%
np.sin(a)
# Out:
# array([[-0.7568025 , -0.95892427, -0.2794155 ],
#        [ 0.84147098,  0.90929743, -0.7568025 ]])

# %%
cot = 1/np.tan(a)
cot
# Out:
# array([[ 0.86369115, -0.29581292, -3.436353  ],
#        [ 0.64209262, -0.45765755,  0.86369115]])

# %%
np.cos(a)
# Out:
# array([[-0.65364362,  0.28366219,  0.96017029],
#        [ 0.54030231, -0.41614684, -0.65364362]])

# %% [markdown]
# ## Rounding Operations

# %%
np.around(cot, 2)
# Out:
# array([[ 0.86, -0.3 , -3.44],
#        [ 0.64, -0.46,  0.86]])

# %%
np.fix(cot)
# Out:
# array([[ 0., -0., -3.],
#        [ 0., -0.,  0.]])

# %%
np.floor(cot)
# Out:
# array([[ 0., -1., -4.],
#        [ 0., -1.,  0.]])

# %%
np.ceil(cot)
# Out:
# array([[ 1., -0., -3.],
#        [ 1., -0.,  1.]])

# %% [markdown]
# ## 2. Matrix Operations

# %%
a,b
# Out:
# (array([[4, 5, 6],
#         [1, 2, 4]]),
#  array([[8, 6, 0],
#         [3, 2, 4]]))

# %%
a*b
# Out:
# array([[32, 30,  0],
#        [ 3,  4, 16]])

# %%
a @ b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 a @ b
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 3)

# %%
b = np.random.randint(0,10, (3,4))

# %%
b
# Out:
# array([[8, 9, 2, 3],
#        [9, 9, 1, 6],
#        [9, 7, 0, 2]], dtype=int32)

# %%
a
# Out:
# array([[4, 5, 6],
#        [1, 2, 4]])

# %%
res = np.dot(a,b)

# %%
res
# Out:
# array([[131, 123,  13,  54],
#        [ 62,  55,   4,  23]])

# %%
a @ b
# Out:
# array([[131, 123,  13,  54],
#        [ 62,  55,   4,  23]])

# %%
a.T
# Out:
# array([[4, 1],
#        [5, 2],
#        [6, 4]])

# %%
np.transpose(a)
# Out:
# array([[4, 1],
#        [5, 2],
#        [6, 4]])

# %%
np.trace(b)
# Out:
# np.int64(17)

# %%
#Inverse of an matrix or array

a_det = np.linalg.det(a)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[38], line 3
#       1 #Inverse of an matrix or array
# ----> 3 a_det = np.linalg.det(a)
#
# File ~\Desktop\DSML\Projects\DS-P1\.venv\Lib\site-packages\numpy\linalg\_linalg.py:2403, in det(a)
#    2357 """
#    2358 Compute the determinant of an array.
#    2359
#    (...)   2400
#    2401 """
#    2402 a = asarray(a)
# -> 2403 _assert_stacked_square(a)
#    2404 t, result_t = _commonType(a)
#    2405 signature = 'D->D' if isComplexType(t) else 'd->d'
#
# File ~\Desktop\DSML\Projects\DS-P1\.venv\Lib\site-packages\numpy\linalg\_linalg.py:246, in _assert_stacked_square(*arrays)
#     243     raise LinAlgError('%d-dimensional array given. Array must be '
#     244             'at least two-dimensional' % a.ndim)
#     245 if m != n:
# --> 246     raise LinAlgError('Last 2 dimensions of the array must be square')
#
# ...

# %%
sq = np.random.randint(0,10, (3,3))
a_det = np.linalg.det(sq)

# %%
inv_sq = np.linalg.inv(sq)

# %%
np.dot(sq,inv_sq)
# Out:
# array([[ 1.00000000e+00,  0.00000000e+00, -2.22044605e-16],
#        [-5.55111512e-17,  1.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]])

# %%
np.dot(sq,inv_sq).round()
# Out:
# array([[ 1.,  0., -0.],
#        [-0.,  1.,  0.],
#        [ 0.,  0.,  1.]])

# %% [markdown]
# solve equation : `4x + 2y = 8` , `5x = 3y = 9`

# %%
a = np.array(
    [
        [4,2],
        [5,3]
    ]
)

b = np.array([8,9])

# %%
a_inv = np.array(a)

# %%
np.dot(a_inv,b)
# Out:
# array([50, 67])

# %%
## Array Broadcasting

# %%
a * b
# Out:
# array([[32, 18],
#        [40, 27]])
