# %% [markdown]
# #

# %%
b = b"\x00\x01\x02\x03\x04\x05"
b = (bytes ([0,1,2,3,4,5])
ba = bytearray(b'\x00\x01\x02\x03\x03\x04\x05')
ba = bytearray([0,1,2,3,4,5])
# Out:
#   Cell In[3], line 2
#     b = (bytes ([0,1,2,3,4,5])
#         ^
# SyntaxError: '(' was never closed

# %%
input()
# Out:
# ''

# %%
age = int(input("Enter your Age"))
# Out:
# Enter your Age 55

# %%
type(age)
# Out:
# int

# %%
5 is 6
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\Suresh\AppData\Local\Temp\ipykernel_22868\2929037671.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   5 is 6
# False

# %%
5==6
# Out:
# False

# %%
x3 = [1,2,3]
y3 = [1,2,3]

# %%
x3 == y3
# Out:
# True

# %%
x3 is y3
# Out:
# False
