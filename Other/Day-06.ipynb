# %%
setA = {4, 5, 6, 7, 8, 1, 1, 2, 1}

# %%
print(setA)
# Out:
# {1, 2, 4, 5, 6, 7, 8}

# %%
setA.add(9)

# %%
setA
# Out:
# {1, 2, 4, 5, 6, 7, 8, 9}

# %%
setA.add(3)

# %%
setA
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
setA.update("ram","Hari")

# %%
setA
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 'H', 'a', 'i', 'm', 'r'}

# %%
setA.pop()
# Out:
# 'i'

# %%
setA.pop()
# Out:
# 1

# %%
SetA
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 SetA
#
# NameError: name 'SetA' is not defined

# %%
setA
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9, 'H', 'a', 'm', 'r'}

# %%
setA.pop("H")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 setA.pop("H")
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
setA.remove("ram")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 setA.remove("ram")
#
# KeyError: 'ram'

# %%
setA
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9, 'H', 'a', 'm', 'r'}

# %%
setA.discard('h')

# %%
setA
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9, 'H', 'a', 'm', 'r'}

# %%
setA.discard("H")

# %%
setA
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9, 'a', 'm', 'r'}

# %%
setA.discard("amr")

# %%
setA
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9, 'a', 'm', 'r'}

# %%
setA.remove("a")

# %%
setA
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9, 'm', 'r'}

# %%
setA.remove("m")

# %%
setA.remove("r")

# %%
setA
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9}

# %%
setA.add(1)

# %%
setA.add(["Ram", "Hari"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 setA.add(["Ram", "Hari"])
#
# TypeError: unhashable type: 'list'

# %%
setA
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
setB = {11, 12, 5, 4, 2, 5, 15, 17}

# %%
setB
# Out:
# {2, 4, 5, 11, 12, 15, 17}

# %%
setAUsetB = setA.unionSetB # |
aUB
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 setAUsetB = setA.unionSetB # |
#       2 aUB
#
# AttributeError: 'set' object has no attribute 'unionSetB'
