# %%
import pandas as pd

#Target Survived 
titanic_df = pd.read_csv("Titanic_Data.csv")

titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Inerting and Deleting Column and Rows

# %% [markdown]
# Dropping a clolumn = deleting

# %%
titanic_df.drop(["PassengerId"], axis = 1, inplace= False)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# Dropping a Row:

titanic_df.drop([0,2,4], axis =0).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 3            4         1       1
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C
# 3      0    113803  53.1000  C123        S
# 5      0    330877   8.4583   NaN        Q
# 6      0     17463  51.8625   E46        S
# 7      1    349909  21.0750   NaN        S

# %%
initials = [name.split(",")[-1].split(".")[0] for name in titanic_df["Name"]]
len(initials)
# Out:
# 891

# %%
titanic_df["initials"] = initials

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked initials
# 0      0         A/5 21171   7.2500   NaN        S       Mr
# 1      0          PC 17599  71.2833   C85        C      Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S     Miss
# 3      0            113803  53.1000  C123        S      Mrs
# ...

# %%
titanic_df.insert(loc=1, column="new_initial", value=initials)

# %%
titanic_df.head()
# Out:
#    PassengerId new_initial  Survived  Pclass  \
# 0            1          Mr         0       3
# 1            2         Mrs         1       1
# 2            3        Miss         1       3
# 3            4         Mrs         1       1
# 4            5          Mr         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked initials
# 0      0         A/5 21171   7.2500   NaN        S       Mr
# 1      0          PC 17599  71.2833   C85        C      Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S     Miss
# ...

# %% [markdown]
# ### Inserting or replacing a Row

# %%
titanic_df.loc[900,:]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Desktop\DSML\Projects\DS-P1\.venv\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 900 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 titanic_df.loc[900,:]
#
# File ~\Desktop\DSML\Projects\DS-P1\.venv\Lib\site-packages\pandas\core\indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
# ...

# %%
titanic_df.head()

# %%
titanic_df.loc[900, :] = [0, 900, "mr", 0, 3, "Ram", "male", 22, 4, 1, "T", 10, "CA", "S", "mr"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 titanic_df.loc[900, :] = [0, 900, "mr", 0, 3, "Ram", "male", 22, 4, 1, "T", 10, "CA", "S", "mr"]
#
# File ~\Desktop\DSML\Projects\DS-P1\.venv\Lib\site-packages\pandas\core\indexing.py:912, in _LocationIndexer.__setitem__(self, key, value)
#     909 self._has_valid_setitem_indexer(key)
#     911 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 912 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\Desktop\DSML\Projects\DS-P1\.venv\Lib\site-packages\pandas\core\indexing.py:1943, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1940 # align and set the values
#    1941 if take_split_path:
#    1942     # We have to operate column-wise
# -> 1943     self._setitem_with_indexer_split_path(indexer, value, name)
#    1944 else:
# ...

# %% [markdown]
# ## Handling Null or Nan or NA values

# %% [markdown]
# 1. Removing Null vlues
# 2. Fill Something (imputation)
# 3. Null as new feature (Feature Engineering)

# %%
titanic_df.isna().sum()
# Out:
# PassengerId      1
# new_initial      1
# Survived         1
# Pclass           1
# Name             1
# Sex              1
# Age            178
# SibSp            1
# Parch            1
# Ticket           1
# Fare             1
# Cabin          688
# Embarked         3
# initials         1
# dtype: int64

# %%
df_filter_1 = titanic_df.dropna(subset = "Embarked", axis=0, ignore_index=True) # delete dropna

# %%
df_filter_1
# Out:
#      PassengerId new_initial  Survived  Pclass  \
# 0            1.0          Mr       0.0     3.0
# 1            2.0         Mrs       1.0     1.0
# 2            3.0        Miss       1.0     3.0
# 3            4.0         Mrs       1.0     1.0
# 4            5.0          Mr       0.0     3.0
# ..           ...         ...       ...     ...
# 884        887.0         Rev       0.0     2.0
# 885        888.0        Miss       1.0     1.0
# 886        889.0        Miss       0.0     3.0
# 887        890.0          Mr       1.0     1.0
# 888        891.0          Mr       0.0     3.0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0    1.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen, Miss. Laina  female  26.0    0.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# ...

# %%
df_filter_1.isna().sum()
# Out:
# PassengerId      0
# new_initial      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# initials         0
# dtype: int64

# %%
titanic_df.Cabin.notna()
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Cabin, Length: 891, dtype: bool

# %%
df_filter_1 ['Cabin'] = titanic_df.Cabin.notna().astype(int)   #replace
# Out:
# C:\Users\Suresh\AppData\Local\Temp\ipykernel_12580\2644634354.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filter_1 ['Cabin'] = titanic_df.Cabin.notna().astype(int)   #replace

# %%
df_filter_1.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         0
# initials         0
# dtype: int64

# %%
# fillup
print(titanic_df.Age.mean())
titanic_df.Age.plot(kind = "hist", bins = 20)
# Out:
# 29.69911764705882
# <Axes: ylabel='Frequency'>

# %%
# BackFill and ForwardFill and Custom Value

df_filter_1["Age"] = df_filter_1["Age"].fillna(mean_age)
# Out:
# C:\Users\Suresh\AppData\Local\Temp\ipykernel_12580\201994157.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filter_1["Age"] = df_filter_1["Age"].fillna(mean_age)

# %%
df_filter_2 = df_filter_1["Age"].fillna(value = mean_age, inplace=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df_filter_2 = df_filter_1["Age"].fillna(value = mean_age, inplace=False)
#
# NameError: name 'mean_age' is not defined

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked initials
# 0      0         A/5 21171   7.2500   NaN        S       Mr
# 1      0          PC 17599  71.2833   C85        C      Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S     Miss
# 3      0            113803  53.1000  C123        S      Mrs
# ...

# %%
titanic_df.initials.value_counts()
# Out:
# initials
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Col               2
# Mlle              2
# Major             2
# Ms                1
# Mme               1
# Don               1
# Lady              1
# Sir               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Name: count, dtype: int64

# %%
titanic_df.replace(
    to_replace=["Dr", "Rev", "Col", "Sir", "Major", "Major", "Mlle"], value="Mr", inplace=True
)
titanic_df.initials.value_counts()
# Out:
# initials
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Col               2
# Mlle              2
# Major             2
# Ms                1
# Mme               1
# Don               1
# Lady              1
# Sir               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Name: count, dtype: int64

# %% [markdown]
# # Data Management
# Type conversion
# dataframe.astype()

# %%
titanic_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# initials        object
# dtype: object

# %% [markdown]
# ### indexing

# %%
df_filter_1.index
# Out:
# RangeIndex(start=0, stop=889, step=1)

# %%
df_filter_1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          887         0       2
# 885          888         1       1
# 886          889         0       3
# 887          890         1       1
# 888          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df_filter_1.set_index("Name")
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df_filter_1.index = df_filter_1.index.astype(str) + "_data"

# %%
df_filter_1
# Out:
#           PassengerId  Survived  Pclass  \
# 0_data              1         0       3
# 1_data              2         1       1
# 2_data              3         1       3
# 3_data              4         1       1
# 4_data              5         0       3
# ...               ...       ...     ...
# 884_data          887         0       2
# 885_data          888         1       1
# 886_data          889         0       3
# 887_data          890         1       1
# 888_data          891         0       3
#
#                                                        Name     Sex  \
# 0_data                              Braund, Mr. Owen Harris    male
# 1_data    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2_data                               Heikkinen, Miss. Laina  female
# 3_data         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4_data                             Allen, Mr. William Henry    male
# ...

# %%
df_filter_1.reset_index
# Out:
# <bound method DataFrame.reset_index of           PassengerId  Survived  Pclass  \
# 0_data              1         0       3
# 1_data              2         1       1
# 2_data              3         1       3
# 3_data              4         1       1
# 4_data              5         0       3
# ...               ...       ...     ...
# 884_data          887         0       2
# 885_data          888         1       1
# 886_data          889         0       3
# 887_data          890         1       1
# 888_data          891         0       3
#
#                                                        Name     Sex  \
# 0_data                              Braund, Mr. Owen Harris    male
# 1_data    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2_data                               Heikkinen, Miss. Laina  female
# 3_data         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4_data                             Allen, Mr. William Henry    male
# ...

# %%
df_filter_1.reset_index(drop=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          887         0       2
# 885          888         1       1
# 886          889         0       3
# 887          890         1       1
# 888          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# ## Renaming Colums

# %%
df_filter_1.columns
# Out:
# Index(['PassengerId', 'new_initial', 'Survived', 'Pclass', 'Name', 'Sex',
#        'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked',
#        'initials'],
#       dtype='object')

# %%
df_filter_1.rename(columns={"Pclass" : "PStatus"})
# Out:
#      PassengerId new_initial  Survived  PStatus  \
# 0            1.0          Mr       0.0      3.0
# 1            2.0         Mrs       1.0      1.0
# 2            3.0        Miss       1.0      3.0
# 3            4.0         Mrs       1.0      1.0
# 4            5.0          Mr       0.0      3.0
# ..           ...         ...       ...      ...
# 884        887.0         Rev       0.0      2.0
# 885        888.0        Miss       1.0      1.0
# 886        889.0        Miss       0.0      3.0
# 887        890.0          Mr       1.0      1.0
# 888        891.0          Mr       0.0      3.0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0    1.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen, Miss. Laina  female  26.0    0.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# ...

# %%
df_filter_1.rename(columns={"PassengerId" : "ID"})
# Out:
#         ID new_initial  Survived  Pclass  \
# 0      1.0          Mr       0.0     3.0
# 1      2.0         Mrs       1.0     1.0
# 2      3.0        Miss       1.0     3.0
# 3      4.0         Mrs       1.0     1.0
# 4      5.0          Mr       0.0     3.0
# ..     ...         ...       ...     ...
# 884  887.0         Rev       0.0     2.0
# 885  888.0        Miss       1.0     1.0
# 886  889.0        Miss       0.0     3.0
# 887  890.0          Mr       1.0     1.0
# 888  891.0          Mr       0.0     3.0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0    1.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen, Miss. Laina  female  26.0    0.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                             Allen, Mr. William Henry    male  35.0    0.0
# ...

# %%
df_filter_1.dtypes
# Out:
# PassengerId    float64
# new_initial     object
# Survived       float64
# Pclass         float64
# Name            object
# Sex             object
# Age            float64
# SibSp          float64
# Parch          float64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# initials        object
# dtype: object

# %%
df_filter_1.to_csv("Cleaned_Titanic.csv", index=True)
