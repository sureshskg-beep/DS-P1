# %%
import pandas as pd

titanic_df = pd.read_csv("final_titanic_data.csv")

# %% [markdown]
# ## Handling data normalization
#
# data normalizatio is the process of transforming data into a common scale or range, to elimanate differences in magnitude and make the data more comparable and interpretable.

# %%
titanic_df.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0  PassengerId  Survived     Sex  Parch     Fare Cabin Embarked
# 0             0          1.0       0.0    male    0.0   7.2500   NaN        S
# 1             1          2.0       1.0  female    0.0  71.2833   C85        C
# 2             2          3.0       1.0  female    0.0   7.9250   NaN        S
# 3             3          4.0       1.0  female    0.0  53.1000  C123        S
# 4             4          5.0       0.0    male    0.0   8.0500   NaN        S
# ..          ...          ...       ...     ...    ...      ...   ...      ...
# 884         884        887.0       0.0    male    0.0  13.0000   NaN        S
# 885         885        888.0       1.0  female    0.0  30.0000   B42        S
# 886         886        889.0       0.0  female    2.0  23.4500   NaN        S
# 887         887        890.0       1.0    male    0.0  30.0000  C148        C
# 888         888        891.0       0.0    male    0.0   7.7500   NaN        Q
#
# ...

# %%
# Slearn

from sklearn.preprocessinge import MinMaxScaler

mm_scaler = MinMaxScaler()

scaled_data = mm_scaler.fit_transform(titanic_df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Slearn
# ----> 3 from sklearn.preprocessinge import MinMaxScaler
#       5 mm_scaler = MinMaxScaler()
#       7 scaled_data = mm_scaler.fit_transform(titanic_df)
#
# ModuleNotFoundError: No module named 'sklearn.preprocessinge'
