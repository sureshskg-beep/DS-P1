# %% [markdown]
# ## Python OS Module
#
# The OS module in python provides a way of interacting with the operating system. It provides a way to access and manpulate files and directoriees, start and stop ...

# %%
import os

# %%
 os.getcwd()
# Out:
# 'C:\\Users\\Suresh\\Desktop\\DSML\\Projects\\DS-P1\\Day-15'

# %%
file_path = "test/file.txt"
if os.path.exists(file_path):
    pass

else: 
    print("File doesn't exist")
# Out:
# File doesn't exist

# %%
pwd
# Out:
# 'C:\\Users\\Suresh\\Desktop\\DSML\\Projects\\DS-P1\\Day-15'

# %%
os.mkdir("test/")

# %%
os.makedires("test\", exist_ok=True)
# Out:
#   Cell In[2], line 1
#     os.makedires("test\", exist_ok=True)
#                  ^
# SyntaxError: unterminated string literal (detected at line 1); perhaps you escaped the end quote?

# %%
pwd
# Out:
# 'C:\\Users\\Suresh\\Desktop\\DSML\\Projects\\DS-P1\\Day-16'

# %%
os.listdrives
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 os.listdrives
#
# NameError: name 'os' is not defined

# %%
import os

# %%
os.listdrives()
# Out:
# ['C:\\', 'E:\\']

# %% [markdown]
# # Working with Environment Variables

# %%
os.environ
# Out:
# environ{'ACLOCAL_PATH': 'C:\\Program Files\\Git\\mingw64\\share\\aclocal;C:\\Program Files\\Git\\usr\\share\\aclocal',
#         'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\Suresh\\AppData\\Roaming',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'SURESH-PC',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'CONFIG_SITE': 'C:/Program Files/Git/etc/config.site',
#         'DISPLAY': 'needs-to-be-defined',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'EFC_25400_1592913036': '1',
#         'EXEPATH': 'C:\\Program Files\\Git',
#         'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer',
#         'FPS_BROWSER_USER_PROFILE_STRING': 'Default',
#         'HOME': 'C:\\Users\\Suresh',
#         'HOMEDRIVE': 'C:',
# ...

# %%
os.environ[MyPass]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 os.environ[MyPass]
#
# NameError: name 'MyPass' is not defined

# %%
os.getenv("OneDrive")
# Out:
# 'C:\\Users\\Suresh\\OneDrive'
